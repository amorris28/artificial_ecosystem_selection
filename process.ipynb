# %%
import numpy as np
import pandas as pd 
conc = pd.read_csv('Data/conc_data.csv')
time = pd.read_csv('Data/time_data.csv')
sc = pd.read_csv('Data/standard_curve.csv')
sc_dates = pd.read_csv('Data/sc_dates.csv')

# %%
import matplotlib.pyplot as plt  
sc
sc_ch4 = sc[sc.molecule == "ch4"]
sc.plot(x='area', y='injection_ppm', style='o')

# Create a Figure and an array of subplots with 2 rows and 2 columns
fig, ax = plt.subplots(2, 2)

# Addressing the top left Axes as index 0, 0, plot month and Seattle precipitation
ax[0, 0].plot(sc.MONTH, seattle_weather.MLY-PRCP-NORMAL)

# In the top right (index 0,1), plot month and Seattle temperatures
ax[0, 1].plot(seattle_weather.MONTH, seattle_weather.MLY-TAVG-NORMAL)

# In the bottom left (1, 0) plot month and Austin precipitations
ax[1, 0].plot(austin_weather.MONTH, austin_weather.MLY-PRCP-NORMAL)

# In the bottom right (1, 1) plot month and Austin temperatures
ax[1, 1].plot(austin_weather.MONTH, austin_weather.MLY-TAVG-NORMAL)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-4c6729d7cffc> in <module>
#       8
#       9 # Addressing the top left Axes as index 0, 0, plot month and Seattle precipitation
# ---> 10 ax[0, 0].plot(sc.MONTH, seattle_weather.MLY-PRCP-NORMAL)
#      11
#      12 # In the top right (index 0,1), plot month and Seattle temperatures
#
# ~/miniconda3/envs/aes/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'MONTH'

# %%
plt.scatter('area', 'injection_ppm', data = sc)
plt.xlabel('Area')
plt.ylabel('Methane Conc (ppm)')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=1/3)

from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit()

# %%
sc[sc.molecule == "ch4"]
# Out:
#      flux_date     sc_date molecule  standard_ppm  injection_ml  \
# 0   2019-09-24  2019-09-24      ch4           999           1.0
# 1   2019-09-24  2019-09-24      ch4           999           0.7
# 2   2019-09-24  2019-09-24      ch4           999           0.5
# 3   2019-09-24  2019-09-24      ch4           999           0.3
# 4   2019-09-24  2019-09-24      ch4           999           0.1
# 10  2019-10-23  2019-10-23      ch4           999           1.0
# 11  2019-10-23  2019-10-23      ch4           999           0.7
# 12  2019-10-23  2019-10-23      ch4           999           0.5
# 13  2019-10-23  2019-10-23      ch4           999           0.3
# 14  2019-10-23  2019-10-23      ch4           999           0.1
# 20  2019-11-19  2019-11-19      ch4           999           1.0
# 21  2019-11-19  2019-11-19      ch4           999           0.7
# 22  2019-11-19  2019-11-19      ch4           999           0.5
# 23  2019-11-19  2019-11-19      ch4           999           0.3
# ...
